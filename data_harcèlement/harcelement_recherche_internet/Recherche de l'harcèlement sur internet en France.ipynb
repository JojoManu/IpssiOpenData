# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (15, 10)

# %%
df = pd.read_csv('multiTimeline.csv', sep=',', index_col='Mois', parse_dates=True)

# %%
df
# Out:
#             harcèlement
# Mois
# 2004-01-01           47
# 2004-02-01           42
# 2004-03-01           55
# 2004-04-01           65
# 2004-05-01           50
# ...                 ...
# 2022-05-01           64
# 2022-06-01           53
# 2022-07-01           33
# 2022-08-01           46
# 2022-09-01           49
#
# [225 rows x 1 columns]

# %%
df.plot(y="harcèlement", xlabel='Année', ylabel="Évolution de l'intérêt")
plt.show()
